# %%
import pandas as pd
import matplotlib.pyplot as plt
import yfinance as yf
# %matplotlib inline

# %%
days = 20
aapl = yf.Ticker('AAPL')
hist = aapl.history(period=f'{days}d')
hist.index = hist.index.strftime('%d %B %Y')
hist = hist[['Close']]
hist.columns = ['apple']
hist = hist.T
hist.index.name = 'Name'
hist
# Out:
# Date   09 April 2021  12 April 2021  13 April 2021  14 April 2021  \
# Name
# apple          133.0     131.240005     134.429993     132.029999
#
# Date   15 April 2021  16 April 2021  19 April 2021  20 April 2021  \
# Name
# apple          134.5     134.160004     134.839996     133.110001
#
# Date   21 April 2021  22 April 2021  23 April 2021  26 April 2021  \
# Name
# apple          133.5     131.940002     134.320007     134.720001
#
# Date   27 April 2021  28 April 2021  29 April 2021  30 April 2021  \
# Name
# apple     134.389999     133.580002     133.479996     131.460007
#
# Date   03 May 2021  04 May 2021  05 May 2021  06 May 2021
# Name
# apple   132.539993   127.849998   128.100006   129.740005

# %%
days =20
tickers = {
    'apple': 'AAPL',
    'facebook': 'FB',
    'microsoft': 'MSFT',
    'google': 'GOOGL',
    'netflix': 'NFLX',
    'amazon': 'AMZN'
}
company = 'apple'
tkr = yf.Ticker(tickers[company])
hist = tkr.history(period=f'{days}d')
hist.index = hist.index.strftime('%d %B %Y')
hist = hist[['Close']]
hist.columns = [company]
hist = hist.T
hist.index.name = 'Name'
hist
# Out:
# Date   09 April 2021  12 April 2021  13 April 2021  14 April 2021  \
# Name
# apple          133.0     131.240005     134.429993     132.029999
#
# Date   15 April 2021  16 April 2021  19 April 2021  20 April 2021  \
# Name
# apple          134.5     134.160004     134.839996     133.110001
#
# Date   21 April 2021  22 April 2021  23 April 2021  26 April 2021  \
# Name
# apple          133.5     131.940002     134.320007     134.720001
#
# Date   27 April 2021  28 April 2021  29 April 2021  30 April 2021  \
# Name
# apple     134.389999     133.580002     133.479996     131.460007
#
# Date   03 May 2021  04 May 2021  05 May 2021  06 May 2021
# Name
# apple   132.539993   127.849998   128.100006   129.740005

# %%
for company in tickers.keys():
    print(company)
# Out:
# apple
# facebook
# microsoft
# google
# netflix
# amazon

# %%
days= 20
tickers = {
    'apple': 'AAPL',
    'facebook': 'FB',
    'microsoft': 'MSFT',
    'google': 'GOOGL',
    'netflix': 'NFLX',
    'amazon': 'AMZN'
}

df = pd.DataFrame()
for company in tickers.keys():
    tkr = yf.Ticker(tickers[company])
    hist = tkr.history(period=f'{days}d')
    hist.index = hist.index.strftime('%d %B %Y')
    hist = hist[['Close']]
    hist.columns = [company]
    hist = hist.T
    hist.index.name = 'Name'
    df = pd.concat([df, hist])

# %%
# Out:
# Date       09 April 2021  12 April 2021  13 April 2021  14 April 2021  \
# Name
# apple         133.000000     131.240005     134.429993     132.029999
# facebook      312.459991     311.540009     309.760010     302.820007
# microsoft     255.850006     255.910004     258.489990     255.589996
# google       2270.669922    2244.620117    2254.429932    2241.909912
# netflix       555.309998     552.780029     553.729980     540.020020
# amazon       3372.199951    3379.389893    3400.000000    3333.000000
#
# Date       15 April 2021  16 April 2021  19 April 2021  20 April 2021  \
# Name
# apple         134.500000     134.160004     134.839996     133.110001
# facebook      307.820007     306.179993     302.239990     302.649994
# microsoft     259.500000     260.739990     258.739990     258.260010
# google       2285.250000    2282.750000    2289.760010    2279.010010
# netflix       549.219971     546.539978     554.440002     549.570007
# amazon       3379.090088    3399.439941    3372.010010    3334.689941
#
# Date       21 April 2021  22 April 2021  23 April 2021  26 April 2021  \
# Name
# apple         133.500000     131.940002     134.320007     134.720001
# facebook      301.470001     296.519989     301.130005     303.040009
# microsoft     260.579987     257.170013     261.149994     261.549988
# google       2278.350098    2252.520020    2299.929932    2309.929932
# netflix       508.899994     508.779999     505.549988     510.299988
# amazon       3362.020020    3309.040039    3340.879883    3409.000000
#
# Date       27 April 2021  28 April 2021  29 April 2021  30 April 2021  \
# Name
# apple         134.389999     133.580002     133.479996     131.460007
# facebook      303.570007     307.100006     329.510010     325.079987
# microsoft     261.970001     254.559998     252.509995     252.179993
# google       2290.979980    2359.040039    2392.760010    2353.500000
# netflix       505.549988     506.519989     509.000000     513.469971
# amazon       3417.429932    3458.500000    3471.310059    3467.419922
#
# Date       03 May 2021  04 May 2021  05 May 2021  06 May 2021
# Name
# apple       132.539993   127.849998   128.100006   129.740005
# facebook    322.579987   318.359985   315.019989   320.019989
# microsoft   251.860001   247.789993   246.470001   249.729996
# google     2343.080078  2306.830078  2314.770020  2337.350098
# netflix     509.109985   503.179993   496.079987   499.549988
# amazon     3386.489990  3311.870117  3270.540039  3306.370117

# %%
days= 20
tickers = {
    'apple': 'AAPL',
    'facebook': 'FB',
    'microsoft': 'MSFT',
    'google': 'GOOGL',
    'netflix': 'NFLX',
    'amazon': 'AMZN'
}

def get_data(days, tickers):
    df = pd.DataFrame()
    for company in tickers.keys():
        tkr = yf.Ticker(tickers[company])
        hist = tkr.history(period=f'{days}d')
        hist.index = hist.index.strftime('%d %B %Y')
        hist = hist[['Close']]
        hist.columns = [company]
        hist = hist.T
        hist.index.name = 'Name'
        df = pd.concat([df, hist])
    return df

# %%
get_data(days=days, tickers=tickers)
# Out:
# Date       09 April 2021  12 April 2021  13 April 2021  14 April 2021  \
# Name
# apple         133.000000     131.240005     134.429993     132.029999
# facebook      312.459991     311.540009     309.760010     302.820007
# microsoft     255.850006     255.910004     258.489990     255.589996
# google       2270.669922    2244.620117    2254.429932    2241.909912
# netflix       555.309998     552.780029     553.729980     540.020020
# amazon       3372.199951    3379.389893    3400.000000    3333.000000
#
# Date       15 April 2021  16 April 2021  19 April 2021  20 April 2021  \
# Name
# apple         134.500000     134.160004     134.839996     133.110001
# facebook      307.820007     306.179993     302.239990     302.649994
# microsoft     259.500000     260.739990     258.739990     258.260010
# google       2285.250000    2282.750000    2289.760010    2279.010010
# netflix       549.219971     546.539978     554.440002     549.570007
# amazon       3379.090088    3399.439941    3372.010010    3334.689941
#
# Date       21 April 2021  22 April 2021  23 April 2021  26 April 2021  \
# Name
# apple         133.500000     131.940002     134.320007     134.720001
# facebook      301.470001     296.519989     301.130005     303.040009
# microsoft     260.579987     257.170013     261.149994     261.549988
# google       2278.350098    2252.520020    2299.929932    2309.929932
# netflix       508.899994     508.779999     505.549988     510.299988
# amazon       3362.020020    3309.040039    3340.879883    3409.000000
#
# Date       27 April 2021  28 April 2021  29 April 2021  30 April 2021  \
# Name
# apple         134.389999     133.580002     133.479996     131.460007
# facebook      303.570007     307.100006     329.510010     325.079987
# microsoft     261.970001     254.559998     252.509995     252.179993
# google       2290.979980    2359.040039    2392.760010    2353.500000
# netflix       505.549988     506.519989     509.000000     513.469971
# amazon       3417.429932    3458.500000    3471.310059    3467.419922
#
# Date       03 May 2021  04 May 2021  05 May 2021  06 May 2021
# Name
# apple       132.539993   127.849998   128.100006   129.740005
# facebook    322.579987   318.359985   315.019989   320.019989
# microsoft   251.860001   247.789993   246.470001   249.729996
# google     2343.080078  2306.830078  2314.770020  2337.350098
# netflix     509.109985   503.179993   496.079987   499.549988
# amazon     3386.489990  3311.870117  3270.540039  3306.370117

# %%
aapl = yf.Ticker('AAPL')

# %%
aapl.info
# Out:
# {'zip': '95014',
#  'sector': 'Technology',
#  'fullTimeEmployees': 100000,
#  'longBusinessSummary': 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. It also sells various related services. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, HomePod, iPod touch, and other Apple-branded and third-party accessories. It also provides AppleCare support services; cloud services store services; and operates various platforms, including the App Store, that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts. In addition, the company offers various services, such as Apple Arcade, a game subscription service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscription news and magazine service; Apple TV+, which offers exclusive original content; Apple Card, a co-branded credit card; and Apple Pay, a cashless payment service, as well as licenses its intellectual property. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It sells and delivers third-party applications for its products through the App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. was founded in 1977 and is headquartered in Cupertino, California.',
#  'city': 'Cupertino',
#  'phone': '408-996-1010',
#  'state': 'CA',
#  'country': 'United States',
#  'companyOfficers': [],
#  'website': 'http://www.apple.com',
#  'maxAge': 1,
#  'address1': 'One Apple Park Way',
#  'industry': 'Consumer Electronics',
#  'previousClose': 128.1,
#  'regularMarketOpen': 127.89,
#  'twoHundredDayAverage': 126.06927,
#  'trailingAnnualDividendYield': 0.0064012487,
#  'payoutRatio': 0.1834,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 129.75,
#  'navPrice': None,
#  'averageDailyVolume10Day': 104445171,
#  'totalAssets': None,
#  'regularMarketPreviousClose': 128.1,
#  'fiftyDayAverage': 128.48059,
#  'trailingAnnualDividendRate': 0.82,
#  'open': 127.89,
#  'toCurrency': None,
#  'averageVolume10days': 104445171,
#  'expireDate': None,
#  'yield': None,
#  'algorithm': None,
#  'dividendRate': 0.88,
#  'exDividendDate': 1620345600,
#  'beta': 1.203743,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 127.1306,
#  'priceHint': 2,
#  'currency': 'USD',
#  'trailingPE': 29.161612,
#  'regularMarketVolume': 75870303,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 2165049262080,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 102151280,
#  'priceToSalesTrailing12Months': 6.6533785,
#  'dayLow': 127.1306,
#  'ask': 130.1,
#  'ytdReturn': None,
#  'askSize': 3000,
#  'volume': 75870303,
#  'fiftyTwoWeekHigh': 145.09,
#  'forwardPE': 24.433146,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': 1.37,
#  'fiftyTwoWeekLow': 75.0525,
#  'bid': 130.05,
#  'tradeable': False,
#  'dividendYield': 0.0069,
#  'bidSize': 900,
#  'dayHigh': 129.75,
#  'exchange': 'NMS',
#  'shortName': 'Apple Inc.',
#  'longName': 'Apple Inc.',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-14400000',
#  'quoteType': 'EQUITY',
#  'symbol': 'AAPL',
#  'messageBoardId': 'finmb_24937',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 6.729,
#  'beta3Year': None,
#  'profitMargins': 0.23451,
#  'enterpriseToEbitda': 21.934,
#  '52WeekChange': 0.65221035,
#  'morningStarRiskRating': None,
#  'forwardEps': 5.31,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 16687599616,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'bookValue': 4.146,
#  'sharesShort': 127937929,
#  'sharesPercentSharesOut': 0.0077,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1601078400,
#  'heldPercentInstitutions': 0.59986,
#  'netIncomeToCommon': 76311003136,
#  'trailingEps': 4.449,
#  'lastDividendValue': 0.205,
#  'SandP52WeekChange': 0.42248273,
#  'priceToBook': 31.292814,
#  'heldPercentInsiders': 0.00075999997,
#  'nextFiscalYearEnd': 1664150400,
#  'mostRecentQuarter': 1616803200,
#  'shortRatio': 1.29,
#  'sharesShortPreviousMonthDate': 1615766400,
#  'floatShares': 16670275864,
#  'enterpriseValue': 2189496549376,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': 1598832000,
#  'lastSplitFactor': '4:1',
#  'legalType': None,
#  'lastDividendDate': 1612483200,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': 1.101,
#  'dateShortInterest': 1618444800,
#  'pegRatio': 1.46,
#  'lastCapGain': None,
#  'shortPercentOfFloat': 0.0077,
#  'sharesShortPriorMonth': 107011007,
#  'impliedSharesOutstanding': None,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'regularMarketPrice': 129.74,
#  'logo_url': 'https://logo.clearbit.com/apple.com'}

# %%
aapl.actions.head()
# Out:
#             Dividends  Stock Splits
# Date
# 1987-05-11   0.000536           0.0
# 1987-06-16   0.000000           2.0
# 1987-08-10   0.000536           0.0
# 1987-11-17   0.000714           0.0
# 1988-02-12   0.000714           0.0

# %%
aapl.dividends.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
aapl.actions['Stock Splits'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
import altair as alt

# %%
df
# Out:
# Date       09 April 2021  12 April 2021  13 April 2021  14 April 2021  \
# Name
# apple         133.000000     131.240005     134.429993     132.029999
# facebook      312.459991     311.540009     309.760010     302.820007
# microsoft     255.850006     255.910004     258.489990     255.589996
# google       2270.669922    2244.620117    2254.429932    2241.909912
# netflix       555.309998     552.780029     553.729980     540.020020
# amazon       3372.199951    3379.389893    3400.000000    3333.000000
#
# Date       15 April 2021  16 April 2021  19 April 2021  20 April 2021  \
# Name
# apple         134.500000     134.160004     134.839996     133.110001
# facebook      307.820007     306.179993     302.239990     302.649994
# microsoft     259.500000     260.739990     258.739990     258.260010
# google       2285.250000    2282.750000    2289.760010    2279.010010
# netflix       549.219971     546.539978     554.440002     549.570007
# amazon       3379.090088    3399.439941    3372.010010    3334.689941
#
# Date       21 April 2021  22 April 2021  23 April 2021  26 April 2021  \
# Name
# apple         133.500000     131.940002     134.320007     134.720001
# facebook      301.470001     296.519989     301.130005     303.040009
# microsoft     260.579987     257.170013     261.149994     261.549988
# google       2278.350098    2252.520020    2299.929932    2309.929932
# netflix       508.899994     508.779999     505.549988     510.299988
# amazon       3362.020020    3309.040039    3340.879883    3409.000000
#
# Date       27 April 2021  28 April 2021  29 April 2021  30 April 2021  \
# Name
# apple         134.389999     133.580002     133.479996     131.460007
# facebook      303.570007     307.100006     329.510010     325.079987
# microsoft     261.970001     254.559998     252.509995     252.179993
# google       2290.979980    2359.040039    2392.760010    2353.500000
# netflix       505.549988     506.519989     509.000000     513.469971
# amazon       3417.429932    3458.500000    3471.310059    3467.419922
#
# Date       03 May 2021  04 May 2021  05 May 2021  06 May 2021
# Name
# apple       132.539993   127.849998   128.100006   129.740005
# facebook    322.579987   318.359985   315.019989   320.019989
# microsoft   251.860001   247.789993   246.470001   249.729996
# google     2343.080078  2306.830078  2314.770020  2337.350098
# netflix     509.109985   503.179993   496.079987   499.549988
# amazon     3386.489990  3311.870117  3270.540039  3306.370117

# %%
companies = ['apple', 'facebook']
data = df.loc[companies]

# %%
data
# Out:
# Date      09 April 2021  12 April 2021  13 April 2021  14 April 2021  \
# Name
# apple        133.000000     131.240005     134.429993     132.029999
# facebook     312.459991     311.540009     309.760010     302.820007
#
# Date      15 April 2021  16 April 2021  19 April 2021  20 April 2021  \
# Name
# apple        134.500000     134.160004     134.839996     133.110001
# facebook     307.820007     306.179993     302.239990     302.649994
#
# Date      21 April 2021  22 April 2021  23 April 2021  26 April 2021  \
# Name
# apple        133.500000     131.940002     134.320007     134.720001
# facebook     301.470001     296.519989     301.130005     303.040009
#
# Date      27 April 2021  28 April 2021  29 April 2021  30 April 2021  \
# Name
# apple        134.389999     133.580002     133.479996     131.460007
# facebook     303.570007     307.100006     329.510010     325.079987
#
# Date      03 May 2021  04 May 2021  05 May 2021  06 May 2021
# Name
# apple      132.539993   127.849998   128.100006   129.740005
# facebook   322.579987   318.359985   315.019989   320.019989

# %%
data.sort_index()
# Out:
# Date      09 April 2021  12 April 2021  13 April 2021  14 April 2021  \
# Name
# apple        133.000000     131.240005     134.429993     132.029999
# facebook     312.459991     311.540009     309.760010     302.820007
#
# Date      15 April 2021  16 April 2021  19 April 2021  20 April 2021  \
# Name
# apple        134.500000     134.160004     134.839996     133.110001
# facebook     307.820007     306.179993     302.239990     302.649994
#
# Date      21 April 2021  22 April 2021  23 April 2021  26 April 2021  \
# Name
# apple        133.500000     131.940002     134.320007     134.720001
# facebook     301.470001     296.519989     301.130005     303.040009
#
# Date      27 April 2021  28 April 2021  29 April 2021  30 April 2021  \
# Name
# apple        134.389999     133.580002     133.479996     131.460007
# facebook     303.570007     307.100006     329.510010     325.079987
#
# Date      03 May 2021  04 May 2021  05 May 2021  06 May 2021
# Name
# apple      132.539993   127.849998   128.100006   129.740005
# facebook   322.579987   318.359985   315.019989   320.019989

# %%
data.T.reset_index()
# Out:
# Name           Date       apple    facebook
# 0     09 April 2021  133.000000  312.459991
# 1     12 April 2021  131.240005  311.540009
# 2     13 April 2021  134.429993  309.760010
# 3     14 April 2021  132.029999  302.820007
# 4     15 April 2021  134.500000  307.820007
# 5     16 April 2021  134.160004  306.179993
# 6     19 April 2021  134.839996  302.239990
# 7     20 April 2021  133.110001  302.649994
# 8     21 April 2021  133.500000  301.470001
# 9     22 April 2021  131.940002  296.519989
# 10    23 April 2021  134.320007  301.130005
# 11    26 April 2021  134.720001  303.040009
# 12    27 April 2021  134.389999  303.570007
# 13    28 April 2021  133.580002  307.100006
# 14    29 April 2021  133.479996  329.510010
# 15    30 April 2021  131.460007  325.079987
# 16      03 May 2021  132.539993  322.579987
# 17      04 May 2021  127.849998  318.359985
# 18      05 May 2021  128.100006  315.019989
# 19      06 May 2021  129.740005  320.019989

# %%
data = data.T.reset_index()

# %%
data.head()
# Out:
# Name           Date       apple    facebook
# 0     09 April 2021  133.000000  312.459991
# 1     12 April 2021  131.240005  311.540009
# 2     13 April 2021  134.429993  309.760010
# 3     14 April 2021  132.029999  302.820007
# 4     15 April 2021  134.500000  307.820007

# %% [markdown]
# ## 日付　企業名　株価　に並び替え

# %%
pd.melt(data, id_vars=['Date'])
# Out:
#              Date      Name       value
# 0   09 April 2021     apple  133.000000
# 1   12 April 2021     apple  131.240005
# 2   13 April 2021     apple  134.429993
# 3   14 April 2021     apple  132.029999
# 4   15 April 2021     apple  134.500000
# 5   16 April 2021     apple  134.160004
# 6   19 April 2021     apple  134.839996
# 7   20 April 2021     apple  133.110001
# 8   21 April 2021     apple  133.500000
# 9   22 April 2021     apple  131.940002
# 10  23 April 2021     apple  134.320007
# 11  26 April 2021     apple  134.720001
# 12  27 April 2021     apple  134.389999
# 13  28 April 2021     apple  133.580002
# 14  29 April 2021     apple  133.479996
# 15  30 April 2021     apple  131.460007
# 16    03 May 2021     apple  132.539993
# 17    04 May 2021     apple  127.849998
# 18    05 May 2021     apple  128.100006
# 19    06 May 2021     apple  129.740005
# 20  09 April 2021  facebook  312.459991
# 21  12 April 2021  facebook  311.540009
# 22  13 April 2021  facebook  309.760010
# 23  14 April 2021  facebook  302.820007
# 24  15 April 2021  facebook  307.820007
# 25  16 April 2021  facebook  306.179993
# 26  19 April 2021  facebook  302.239990
# 27  20 April 2021  facebook  302.649994
# 28  21 April 2021  facebook  301.470001
# 29  22 April 2021  facebook  296.519989
# 30  23 April 2021  facebook  301.130005
# 31  26 April 2021  facebook  303.040009
# 32  27 April 2021  facebook  303.570007
# 33  28 April 2021  facebook  307.100006
# 34  29 April 2021  facebook  329.510010
# 35  30 April 2021  facebook  325.079987
# 36    03 May 2021  facebook  322.579987
# 37    04 May 2021  facebook  318.359985
# 38    05 May 2021  facebook  315.019989
# 39    06 May 2021  facebook  320.019989

# %%
data = pd.melt(data, id_vars=['Date']).rename(columns={'value': 'Stock Prices(USD)'})
data.head()
# Out:
#             Date   Name  Stock Prices(USD)
# 0  09 April 2021  apple         133.000000
# 1  12 April 2021  apple         131.240005
# 2  13 April 2021  apple         134.429993
# 3  14 April 2021  apple         132.029999
# 4  15 April 2021  apple         134.500000

# %%
chart = (
    alt.Chart(data)
    .mark_line(opacity=0.8)
    .encode(
        x="Date:T",
        y=alt.Y("Stock Prices(USD):Q", stack=None),
        color="Name:N"
    )
)

# %%
chart
# Out:
# alt.Chart(...)

# %%
ymin, ymax = 280, 350

chart = alt.Chart(data).mark_line(opacity=0.8, clip=True).encode(
        x="Date:T",
        y=alt.Y("Stock Prices(USD):Q", stack=None, scale=alt.Scale(domain=[ymin,ymax])),
        color="Name:N"
    )

# %%
chart
# Out:
# alt.Chart(...)
